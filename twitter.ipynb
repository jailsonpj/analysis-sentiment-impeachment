# %%
from twython import Twython,TwythonError
import pandas as pd

# %%
CONSUMER_KEY="QR5fsBnBCqD3Rda6szBchJCdW"
CONSUMER_SECRET="13FYl5BN0QGd43X1qNhMPSZrjH2Virgo7uHKREv3aKPO3tmBKL"

twitter = Twython(CONSUMER_KEY,CONSUMER_SECRET)


#procura por tweets contendo a palavra python
for status in twitter.search(q='"python"')["statuses"]:
    user = status["user"]["screen_name"]
    text = status["text"]
    print(user,":",text)
    print()

''''results = twitter.cursor(twitter.search,q='python')

for result in results:
    user = result["user"]["screen_name"]
    text = result["text"]
    print(user,":",text)
    print()'''
# Out:
# AstrosBrain : @Dwest2828 Oh I know Python.
#
# rabinsxp : Arithmetic Operations and Variable Assignments in Python https://t.co/OY6aYbXyEX via @rabinsxp
#
# o_sese : RT @SKSolaKuti: So python ate JAMB’s N36m?
#
# Under Buhari even python don dey chop govt money..
#
# Nothing we won’t hear
#
# Baboon and dogs
# Rat…
#
# quantlabs : I added a video to a @YouTube playlist https://t.co/7P4p0SgsnM Why ccxt in Python for Bitcoin crypto currency bot development over
#
# rds1963 : RT @BaseballQuotes1: The other guys, all they have to do is use their big butts and big python arms to hit homers. Me, I'm the little guy i…
#
# bxk259 : All these softwares like R, SAS, SPSS, python etc. are enabling people to run statistical tests without understandi… https://t.co/Pq73R3cV8d
#
# Tsundu_Mak : RT @greatnews2017: COMPLETE GUIDE TO #TENSORFLOW FOR DEEP LEARNING WITH PYTHON
# https://t.co/vtb3QoAMkE https://t.co/Bxhlt4r2FJ
#
# Dwest2828 : @AstrosBrain Ever learned Python?
#
# suzushiroz : JAVA,python,ruby,chikubi
#
# Carmenferala : RT @dani_agitpro: Si 'La vida de Brian' de los Monty Python se hubiese estrenado en 2018 en vez de en 1979:
#
# - El protagonista sería conden…
#
# HARDCOREBIAFRA1 : RT @AnyikingsI: The Biafra Post: OPERATION PYTHON DANCE III https://t.co/GQuWKRZ6CO
#
# FinesNoel : RT @blackgayvideo: Python dickin down Rocky in "Nasty Ass Big Dick Fuck'n" Nasty Ass Big Dick Fuck'n @videoboyblog #dawgPoundUSA https://t.…
#
# impwalker77 : RT @dhh: Here’s a complete shocker: It’s possible to fancy more than one programming language AT THE SAME TIME. I know, heresy. I love Ruby…
#
# lucklepper : RT @PythonInTheWyld: "Thinking Machine supercomputers and gene sequencers break down the strand in minutes..."
# #Python #Perl #BioInformatic…
# '\'results = twitter.cursor(twitter.search,q=\'python\')\n\nfor result in results:\n    user = result["user"]["screen_name"]\n    text = result["text"]\n    print(user,":",text)\n    print()'

# %%
#verifica a timeline do usuário
CONSUMER_KEY="QR5fsBnBCqD3Rda6szBchJCdW"
CONSUMER_SECRET="13FYl5BN0QGd43X1qNhMPSZrjH2Virgo7uHKREv3aKPO3tmBKL"
ACCESS_TOKEN = "231448840-l12SVUES8llIvk136fktswGHUvCOl6UbYCW5CLz7"
ACCESS_SECRET = "vJpuj4jvzKA7DhyQmucxfWRntyF4jDMvDhEmM0EfiTntG"

twitter = Twython(CONSUMER_KEY,CONSUMER_SECRET,ACCESS_TOKEN,ACCESS_SECRET)

#pesquisa timeline de um usurio
try:
    user_timeline = twitter.get_user_timeline(screen_name='julianyraiol')
except TwythonError as e:
    print(e)
#print(user_timeline)
df = pd.DataFrame(user_timeline)

# %%
df
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sat Feb 10 06:53:23 +0000 2018
# 1         None        None  Sat Feb 10 01:19:14 +0000 2018
# 2         None        None  Sat Feb 10 01:03:04 +0000 2018
# 3         None        None  Fri Feb 09 06:49:50 +0000 2018
# 4         None        None  Fri Feb 09 02:04:38 +0000 2018
# 5         None        None  Thu Feb 08 02:06:12 +0000 2018
# 6         None        None  Tue Feb 06 15:52:44 +0000 2018
# 7         None        None  Tue Feb 06 01:14:02 +0000 2018
# 8         None        None  Tue Feb 06 01:13:11 +0000 2018
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
# 5  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6  {'hashtags': [], 'symbols': [], 'user_mentions...
# 7  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               2
# 2  {'media': [{'id': 961962573536088065, 'id_str'...               0
# 3                                                NaN               1
# 4                                                NaN               0
# 5  {'media': [{'id': 960991954283745280, 'id_str'...               0
# 6  {'media': [{'id': 960278542171983872, 'id_str'...               0
# 7                                                NaN               0
# 8                                                NaN               1
#
#    favorited   geo                  id              id_str  \
# 0      False  None  962217917902450689  962217917902450689
# 1      False  None  962133828142759936  962133828142759936
# 2      False  None  962129758120300544  962129758120300544
# 3      False  None  961854637400666112  961854637400666112
# 4      False  None  961782864084860929  961782864084860929
# 5      False  None  961420870152486913  961420870152486913
# 6      False  None  960904096709570560  960904096709570560
# 7      False  None  960682966346272768  960682966346272768
# 8      False  None  960682753447682048  960682753447682048
#
#                          ...                         lang  place  \
# 0                        ...                           pt   None
# 1                        ...                           pt   None
# 2                        ...                           pt   None
# 3                        ...                           pt   None
# 4                        ...                           pt   None
# 5                        ...                           pt   None
# 6                        ...                           pt   None
# 7                        ...                           pt   None
# 8                        ...                           pt   None
#
#   possibly_sensitive  retweet_count retweeted  \
# 0                NaN              0     False
# 1                NaN              0     False
# 2              False          49800     False
# 3                NaN              0     False
# 4                NaN              1     False
# 5              False           1258     False
# 6              False           1360     False
# 7                NaN              0     False
# 8                NaN              0     False
#
#                                     retweeted_status  \
# 0                                                NaN
# 1                                                NaN
# 2  {'created_at': 'Fri Feb 09 13:58:51 +0000 2018...
# 3                                                NaN
# 4  {'created_at': 'Fri Feb 09 00:51:26 +0000 2018...
# 5  {'created_at': 'Tue Feb 06 21:43:09 +0000 2018...
# 6  {'created_at': 'Sun Feb 04 22:27:04 +0000 2018...
# 7                                                NaN
# 8                                                NaN
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com" rel="nofollow">Tw...
# 5  <a href="http://twitter.com/download/android" ...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/android" ...
# 8  <a href="http://twitter.com/download/android" ...
#
#                                                 text truncated  \
# 0  Uma pena é lembrar q eu vou acordar daqui a po...     False
# 1  @no_shapes Mano, só merendo tomando toddynho h...     False
# 2  RT @FelipeLM20: Gente, vamos ajudar no RT até ...     False
# 3                                        B o l a d a     False
# 4  RT @luizbenttes: Paguei meus boletos e sobrou ...     False
# 5  RT @zelune: "seu uber está terminando uma viag...     False
# 6  RT @yungxcost: eu quando chega a parte de bad ...     False
# 7                       @jesscrvg_ KKKKKK como assim     False
# 8         @chatidissimo Eu ouvindo lady gaga huaahua     False
#
#                                                 user
# 0  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 1  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 2  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 3  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 4  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 5  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 6  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 7  {'id': 3214549276, 'id_str': '3214549276', 'na...
# 8  {'id': 3214549276, 'id_str': '3214549276', 'na...
#
# [9 rows x 26 columns]

# %%
# Requires Authentication as of Twitter API v1.1
# Pesquisa de twetts com o método twitter.search


CONSUMER_KEY="QR5fsBnBCqD3Rda6szBchJCdW"
CONSUMER_SECRET="13FYl5BN0QGd43X1qNhMPSZrjH2Virgo7uHKREv3aKPO3tmBKL"
ACCESS_TOKEN = "231448840-l12SVUES8llIvk136fktswGHUvCOl6UbYCW5CLz7"
ACCESS_SECRET = "vJpuj4jvzKA7DhyQmucxfWRntyF4jDMvDhEmM0EfiTntG"
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_SECRET)
try:
    search_results = twitter.search(q='carnaval', count=50)
except TwythonError as e:
    print(e)

for tweet in search_results['statuses']:
    print ('Tweet from @%s Date: %s' % (tweet['user']['screen_name'],tweet['created_at']))
    print(tweet['text'])
    print()
# Out:
# Tweet from @coehugo_ Date: Sun Feb 11 20:43:35 +0000 2018
# RT @Nabrisa1kilo: Que carnaval desanimante
#
# Tweet from @curiousNeto Date: Sun Feb 11 20:43:35 +0000 2018
# @netonightmare Nesse carnaval eu vou tá é caçando e analisando mulheres.
#
# Tweet from @Max_Gama Date: Sun Feb 11 20:43:35 +0000 2018
# O Rio é o meu País. Ponta da Urca, Job and Carnaval. #PostagensUrbanas #Delirios #SemFiltro #021… https://t.co/LraMGDDysV
#
# Tweet from @ana_cafiero Date: Sun Feb 11 20:43:35 +0000 2018
# RT @_brisasantos: Vo parar de beber dps do carnaval
#
# Tweet from @AnnaSan18092028 Date: Sun Feb 11 20:43:34 +0000 2018
# Sobre o Carnaval de Hojee https://t.co/ZaCr9JpaNP
#
# Tweet from @luciacmora Date: Sun Feb 11 20:43:34 +0000 2018
# RT @luisoliveros13: Bs. 53 millardos se va a gastar la alcaldesa de Caracas en fiesta de carnaval.
# Imaginen la cantidad de medicinas que s…
#
# Tweet from @GladysCastanho Date: Sun Feb 11 20:43:34 +0000 2018
# RT @FotosDeFatos: Música tocada nas ruas de SP e Rio de Janeiro durante o carnaval de 1920, a canção encontra-se no livro "A Música Popular…
#
# Tweet from @NorteRadioTruji Date: Sun Feb 11 20:43:34 +0000 2018
# Huertas de Ánimas ha realizado su desfile de carnaval.
# Los premios han recaido en:
# El individual "el... https://t.co/ssVbaqPsGz
#
# Tweet from @Pablontj15 Date: Sun Feb 11 20:43:34 +0000 2018
# RT @beagomesdm: o carnaval no Rio de Janeiro............ https://t.co/vBRVjFiK11
#
# Tweet from @i_dnt_g1v3_a_fk Date: Sun Feb 11 20:43:34 +0000 2018
# Sinceramente não tenho interesse nenhum no carnaval.
#
# Tweet from @Claraana_silva Date: Sun Feb 11 20:43:34 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @recheortega Date: Sun Feb 11 20:43:34 +0000 2018
# Domingo de carnaval curtindo a minha Triumph🇬🇧 Tiger #Triumph #triumphmotorcycles #triumphtiger… https://t.co/ybq6Idxa0o
#
# Tweet from @_millajujuu Date: Sun Feb 11 20:43:34 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @HugooSoares77 Date: Sun Feb 11 20:43:34 +0000 2018
# RT @jessicamoraism: Carnaval decente só no rio mesmo, um dia vou lá por esta altura
#
# Tweet from @manumedeiross_ Date: Sun Feb 11 20:43:34 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @wakestalia Date: Sun Feb 11 20:43:34 +0000 2018
# RT @guilhermesousa: guerra na rocinha #carnaval https://t.co/dHMNHFGCB4
#
# Tweet from @mrvalbak Date: Sun Feb 11 20:43:33 +0000 2018
# galera problematizando as fantasias no carnaval. odeio problematizadores muito fervorosos e odeio carnaval
# eu tô as… https://t.co/kHD0BS76nH
#
# Tweet from @gringazada Date: Sun Feb 11 20:43:33 +0000 2018
# RT @beagomesdm: o carnaval no Rio de Janeiro............ https://t.co/vBRVjFiK11
#
# Tweet from @analuuizagp Date: Sun Feb 11 20:43:33 +0000 2018
# RT @bielz3_: SIM É CARNAVAL QUE FALA SUA DESGRAÇAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA VAI TOMA NO CU PORRA
#
# Tweet from @DantaasGiovanna Date: Sun Feb 11 20:43:33 +0000 2018
# RT @Perihlok: Que belo carnaval né minha Gnt!❤️😴
#
# Tweet from @liaperrotta Date: Sun Feb 11 20:43:33 +0000 2018
# RT @myqueenmisha: "vai passa o carnaval onde?" https://t.co/PViVuCnU7l
#
# Tweet from @gabriewborg Date: Sun Feb 11 20:43:33 +0000 2018
# RT @ZIPERATIVOBR: melhor gif do carnaval é o da anitta tampando a claudia leitte, rainha da exibição #Globeleza https://t.co/yCYjcyYgIo
#
# Tweet from @sandrelle_silva Date: Sun Feb 11 20:43:33 +0000 2018
# Literalmente o pior Carnaval de todos !
#
# Tweet from @felippe_spfc Date: Sun Feb 11 20:43:33 +0000 2018
# RT @CLamentaveis: Bruxo no auge do carnaval, até chorando de tão bêbado 😂
# .
# GENTE COMO A GENTE!
# .
# Como não amar? https://t.co/RubvrrA2fD
#
# Tweet from @beatrizgi_ Date: Sun Feb 11 20:43:33 +0000 2018
# quem me dera passar o carnaval no rio
#
# Tweet from @Bia_Lago14 Date: Sun Feb 11 20:43:32 +0000 2018
# RT @imHaruyuki: passei o carnaval deitado e tá sendo top
#
# Tweet from @jwcepotter Date: Sun Feb 11 20:43:32 +0000 2018
# RT @rosescamilizers: eu no carnaval https://t.co/YEwXYfCeNM
#
# Tweet from @vitoriamarrtins Date: Sun Feb 11 20:43:32 +0000 2018
# RT @luscas: “eh carnaval que chama né?”
#
# não... eh cleyton
#
# Tweet from @MariaPaula_223 Date: Sun Feb 11 20:43:32 +0000 2018
# RT @Vieeiraffc: Carnaval é bom pra todo mundo. Os crentes vão pro retiro, os foliões vão pra folia e os nerds vão assistir série. Não sei p…
#
# Tweet from @claud1no Date: Sun Feb 11 20:43:32 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @bkw_la Date: Sun Feb 11 20:43:32 +0000 2018
# RT @lawrenconha: meu carnaval em quatro imagens https://t.co/ixUoB4VGAn
#
# Tweet from @Pietra_Abacaxi Date: Sun Feb 11 20:43:32 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @lcruzz23 Date: Sun Feb 11 20:43:31 +0000 2018
# Como é carnaval meteram um palhaço a arbitrar o jogo
#
# Tweet from @ComMCorreaS3 Date: Sun Feb 11 20:43:31 +0000 2018
# RT @senafrontpanama: Disfruta el carnaval con responsabilidad y tolerancia, si vas a exponerte al sol, mantente hidratado y protégete, util…
#
# Tweet from @carlosbritto1 Date: Sun Feb 11 20:43:31 +0000 2018
# Esquema de segurança garante tranquilidade dos foliões no Carnaval 2018 de Petrolina https://t.co/Nm4INuBsAv https://t.co/UoyXJuYfgI
#
# Tweet from @Betcomis_asd Date: Sun Feb 11 20:43:31 +0000 2018
# RT @Rafnats: @RuPaul at Brazilian Carnaval https://t.co/62Qk7AI0gL
#
# Tweet from @Karol71449211 Date: Sun Feb 11 20:43:31 +0000 2018
# RT @NonLacerda: Claudia Leitte: "Esse carnaval serei o único assunto"
#
# Carnaval :
# Gêmeas de Ivete Sangalo nascem em Salvador https://t.co/y…
#
# Tweet from @abreumilena1 Date: Sun Feb 11 20:43:31 +0000 2018
# RT @lucasfacanhas: Carnaval tá aí né...! https://t.co/W7Z2veK5NF
#
# Tweet from @danielb086 Date: Sun Feb 11 20:43:31 +0000 2018
# Tinha tudo p ficar em casa mas é carnaval como q faz em hahahahahah
#
# Tweet from @LauraWXavier Date: Sun Feb 11 20:43:31 +0000 2018
# RT @em_com: Homem precisa ser resgatado depois de se afogar em fonte na Praça da Liberdade
# https://t.co/16XipNF59l https://t.co/Qs6YMxXsRn
#
# Tweet from @KarlVillano Date: Sun Feb 11 20:43:31 +0000 2018
# RT @LuchoPanero10: #LaBarraBoliche #Carnaval
# Lista Free Lucho Panero hasta las 2 am
# Arma tu lista al 3512084395 https://t.co/RiUFMyM08T
#
# Tweet from @fallingapartime Date: Sun Feb 11 20:43:31 +0000 2018
# RT @cacoveroni: minha namorada pediu um tempo pra pensar na nossa relação durante esse carnaval
# coitada, justo nessa época que é pra festej…
#
# Tweet from @Ativo_Puto Date: Sun Feb 11 20:43:31 +0000 2018
# Carnaval é um lixo...
# Pra quem ta perguntando se tou curtindo o carnaval...
#
# Tweet from @kaliforniaguns Date: Sun Feb 11 20:43:31 +0000 2018
# RT @Vieeiraffc: Carnaval é bom pra todo mundo. Os crentes vão pro retiro, os foliões vão pra folia e os nerds vão assistir série. Não sei p…
#
# Tweet from @luizalobaopenal Date: Sun Feb 11 20:43:31 +0000 2018
# RT @luscas: “eh carnaval que chama né?”
#
# não... eh cleyton
#
# Tweet from @Carlinhos_1930 Date: Sun Feb 11 20:43:31 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @oreozinbyoreo Date: Sun Feb 11 20:43:31 +0000 2018
# RT @maiconkusterkkk: mano o cara foi p carnaval fantasiado de rato tomando banho como assim https://t.co/jtNYBZuHju
#
# Tweet from @yoongichrist Date: Sun Feb 11 20:43:30 +0000 2018
# RT @gottaccabeyo: Casal gay de mãos dadas na rua: um desrespeito, se não querem sofrer preconceito não façam isso respeitem as crianças.…
#
# Tweet from @darkboards Date: Sun Feb 11 20:43:30 +0000 2018
# RT @lawrenconha: meu carnaval em quatro imagens https://t.co/ixUoB4VGAn
#
# Tweet from @rxcarlos Date: Sun Feb 11 20:43:30 +0000 2018
# RT @bielz3_: SIM É CARNAVAL QUE FALA SUA DESGRAÇAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA VAI TOMA NO CU PORRA
