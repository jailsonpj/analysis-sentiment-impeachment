# %%
import pandas as pd
import numpy as np

# %%
dados_twitter = pd.read_csv('10.692.csv',encoding="ISO-8859-1")

# %%
dados_twitter.head()
# Out:
#    Unnamed: 0                                               text  favorited  \
# 0           1  RT @Simon_Bolivar69: Â¡SEGUID EL EJEMPLO DE BR...      False
# 1           2  RT @GenPenaloza: BRASIL Ola de protestas con m...      False
# 2           3  RT @letrapreta: Se eu fosse a Dilma agora chut...      False
# 3           4  RT @tdevilsadvocat: gente que absurdo essa moÃ...      False
# 4           5  RT @SureKamhunga: Biggest protest in Brazil hi...      False
#
#    favoriteCount replyToSN              created  truncated  replyToSID  \
# 0              0       NaN  2016-03-14 08:12:24      False         NaN
# 1              0       NaN  2016-03-14 08:12:22      False         NaN
# 2              0       NaN  2016-03-14 08:12:17      False         NaN
# 3              0       NaN  2016-03-14 08:12:12      False         NaN
# 4              0       NaN  2016-03-14 08:12:12      False         NaN
#
#                    id  replyToUID  \
# 0  709291074884411392         NaN
# ...

# %%
#filtrando dados para twittes que tiveream rt acima de 1000


dados_twitter.loc[dados_twitter['retweetCount'] > 1000]
# Out:
#       Unnamed: 0                                               text  \
# 2              3  RT @letrapreta: Se eu fosse a Dilma agora chut...
# 319          320  RT @Yusnaby: ÃLTIMAHORA: Toda #Brasil estÃ¡ e...
# 651          652  RT @Yusnaby: ÃLTIMAHORA: Toda #Brasil estÃ¡ e...
# 679          680  RT @letrapreta: Se eu fosse a Dilma agora chut...
# 767          768  RT @letrapreta: Se eu fosse a Dilma agora chut...
# 957          958  RT @letrapreta: Se eu fosse a Dilma agora chut...
# 1080        1081  RT @Yusnaby: AHORA en #Brasilia: multitudinari...
# 1142        1143  RT @letrapreta: Se eu fosse a Dilma agora chut...
# 1360        1361                            RT @ClaroBrasil: #DILMA
# 1610        1611  RT @letrapreta: Se eu fosse a Dilma agora chut...
# 1699        1700  RT @FroederManu: Ah, se o problema fosse sÃ³ a...
# 1749        1750  RT @Yusnaby: AHORA en #Brasilia: multitudinari...
# 1806        1807  RT @Yusnaby: ÃLTIMAHORA: Toda #Brasil estÃ¡ e...
# ...

# %%
dados_twitter2 = pd.read_csv('28.074.csv',encoding="ISO-8859-1")
dados_twitter3 = pd.read_csv('33.506.csv',encoding='ISO-8859-1')
dados_twitter4 = pd.read_csv('40.496.csv',encoding="ISO-8859-1")

# %%
dados_twitter2
# Out:
#       Unnamed: 0                                               text  \
# 0              1  .@marcelofalak en #CiudadanoComÃºn "Brasil est...
# 1              2  #timbeta OperaÃ§Ã£o Lava Jato: Procurador-gera...
# 2              3  RT @pedroandradetv: Dilma alega que"repudia co...
# 3              4  RT @Estadao: Dilma diz que Mercadante agiu soz...
# 4              5  #timbeta OperaÃ§Ã£o Lava Jato: Procurador-gera...
# 5              6  RT @cleanil: Dilma fez de tudo pra acabar com ...
# 6              7  RT @RevistaISTOE: DelcÃ­dio: "Fui escalado por...
# 7              8  RT @g1: Dilma recebe Lula no Alvorada para tra...
# 8              9  RT @Karlmarxbr_Br: Citam Diretas JÃ¡ e fora Co...
# 9             10  #timbeta OperaÃ§Ã£o Lava Jato: Procurador-gera...
# 10            11  RT @Informe_Brasil: OperaÃ§Ã£o Lava Jato: Proc...
# 11            12  #timbeta OperaÃ§Ã£o Lava Jato: Procurador-gera...
# 12            13  RT @panjokermeso: Dilma Ã© ameaÃ§a a todos ele...
# ...

# %%
#filtrando twitters para o usuário do jornal Estadão, versão online do jornal O Estado de São Paulo

estadao = dados_twitter2.loc[dados_twitter2['screenName'] == 'Estadao']

# %%
estadao
# Out:
#       Unnamed: 0                                               text  \
# 4546        4547  Dilma diz que Mercadante agiu sozinho ao procu...
#
#       favorited  favoriteCount replyToSN              created  truncated  \
# 4546      False             55       NaN  2016-03-15 21:35:50      False
#
#       replyToSID                  id  replyToUID  \
# 4546         NaN  709855652131282944         NaN
#
#                                            statusSource screenName  \
# 4546  <a href="https://about.twitter.com/products/tw...    Estadao
#
#       retweetCount  isRetweet  retweeted  longitude  latitude
# 4546            41      False      False        NaN       NaN

# %%
#filtrando twitters para o usuário do jornal Folha versão online do jornal O Folha de São Paulo
folha = dados_twitter3.loc[dados_twitter3['screenName'] == 'folha']

# %%
folha
# Out:
#       Unnamed: 0                                               text  \
# 2467        2468  MÃ´nica Bergamo: Lula deve aceitar convite de ...
# 3244        3245  Lula decide viajar a BrasÃ­lia para discutir c...
# 3645        3646  Lula decide viajar a BrasÃ­lia para discutir c...
#
#       favorited  favoriteCount replyToSN              created  truncated  \
# 2467      False             40       NaN  2016-03-14 21:41:40      False
# 3244      False             48       NaN  2016-03-14 21:34:59      False
# 3645      False             40       NaN  2016-03-14 21:31:02      False
#
#       replyToSID                  id  replyToUID  \
# 2467         NaN  709494731965861889         NaN
# 3244         NaN  709493050473619456         NaN
# 3645         NaN  709492056507469825         NaN
#
#                                            statusSource screenName  \
# 2467  <a href="https://about.twitter.com/products/tw...      folha
# ...

# %%
folha['text'][2467]
# Out:
# 'MÃ´nica Bergamo: Lula deve aceitar convite de Dilma para ser ministro https://t.co/RdPYaqwc18 https://t.co/yk224GJ2ZM'
